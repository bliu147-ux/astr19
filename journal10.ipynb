# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.standard_gamma((0.4),1000)

# %%
plt.hist(x,bins=100)
plt.xlabel('x')
plt.ylabel('# of x occurrences')
plt.savefig('journal10.pdf',bbox_inches='tight',dpi=600)
