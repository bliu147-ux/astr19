# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.standard_gamma((0.4),1000)

# %%
plt.hist(x,bins=100)
plt.xlabel('x')
plt.ylabel('# of x occurrences')
# Out:
# Text(0, 0.5, '# of x occurrences')
