# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(low=0.0,high=1.0,size=1000)

# %%
f, ax = plt.subplots(1,1,figsize=(5,5))
ax.hist(x,bins=100)
ax.set_xlabel('uniform distribution between 0 and 1')
ax.set_ylabel('number of occurrences for some value of x
# Out:
# (array([ 9.,  7.,  8., 13., 11., 15., 12.,  8., 10.,  8.,  8., 13.,  2.,
#          7., 14., 13.,  3., 10.,  9., 11., 19.,  8.,  9., 13.,  9., 16.,
#         11.,  5., 10., 13., 11., 12., 12., 13., 10.,  6., 11., 11.,  9.,
#          7., 10.,  8., 13.,  7.,  9.,  7.,  6., 17.,  8., 13., 12., 11.,
#         10.,  5.,  7., 10.,  8., 10.,  9., 11., 12., 11., 10.,  9.,  8.,
#         10., 10., 14.,  6.,  9., 17., 13.,  9.,  8., 14.,  8.,  9., 12.,
#          7., 10., 10., 11., 13.,  7., 12.,  5.,  9.,  6.,  6., 12., 13.,
#          9., 12., 11.,  8.,  6., 10., 19., 11.,  7.]),
#  array([6.18692383e-05, 1.00587664e-02, 2.00556635e-02, 3.00525606e-02,
#         4.00494577e-02, 5.00463548e-02, 6.00432519e-02, 7.00401490e-02,
#         8.00370462e-02, 9.00339433e-02, 1.00030840e-01, 1.10027737e-01,
#         1.20024635e-01, 1.30021532e-01, 1.40018429e-01, 1.50015326e-01,
#         1.60012223e-01, 1.70009120e-01, 1.80006017e-01, 1.90002914e-01,
# ...

# %% [markdown]
# def histogram(x,
#               save_flag=True,
#               xlabel='x',
#               ylabel='y',
#               lcolor='red',
#               fs=14,
#               fname='histogram.pdf'):
#     f, ax = plt.subplots(1,1,figsize=(5,5))
#     #ax.set_xlim(-10,10)
#     ax.hist(x,facecolor=lcolor,bins=100,alpha=0.5)
#     ax.set_position()
#     ax.set_xlabel(xlabel,fontsize=fs)
#     ax.set_ylabel(ylabel,fontsize=fs)
#         #plt.savefig(fname,bbox_inches='tight',dpi=400)
#
# def main():
#     x = np.random.normal(scale=1,size=1000)
#     histogram(x)
#
# main()
